# %% [markdown]
# ### Main reference
# https://developer.linkedin.com/docs/v1/jobs/job-lookup-api-and-fields

# %%
from faker import Faker
import uuid 
import pandas as pd

import random

# %%
job_list = ['421125-Operador de caixa',
 '411005-Auxiliar de escritório',
 '411005-Auxiliar administrativo',
 '521110-Vendedor de comércio varejista',
 '411010-Assistente administrativo',
 '391115-Controlador de entrada e saída',
 '514320-Faxineiro',
 '514320-Auxiliar de limpeza',
 '513205-Cozinheiro geral',
 '513435-Atendente de lanchonete',
 '422105-Recepcionista atendente',
 '414105-Almoxarife',
 '512105-Empregado  doméstico  nos serviços gerais',
 '354125-Assistente de vendas',
 '422105-Recepcionista, em geral',
 '414125-Estoquista',
 '784205-Alimentador de linha de produção',
 '414140-Auxiliar de logistica',
 '513405-Garçom',
 '521125-Repositor de mercadorias',
 '715210-Pedreiro',
 '517330-Vigilante',
 '513505-Auxiliar nos serviços de alimentação',
 '513505-Auxiliar de cozinha',
 '422310-Operador de telemarketing ativo e receptivo',
 '414105-Estoquista',
 '514325-Oficial de serviços gerais na manutenção de edificações',
 '142105-Gerente administrativo',
 '717020-Servente de obras',
 '521140-Atendente de lojas e mercados',
 '513505-Ajudante de cozinha',
 '410105-Supervisor administrativo',
 '782510-Motorista de caminhão ',
 '621005-Trabalhador agropecuário em geral',
 '513425-Copeiro',
 '414105-Auxiliar de almoxarifado',
 '411005-AUXILIAR DE ESCRITORIO, EM GERAL',
 '141415-Gerente de loja e supermercado',
 '142305-Gerente comercial',
 '342125-Assistente de logística de transporte',
 '521105-VENDEDOR EM COMERCIO ATACADISTA',
 '517410-Porteiro de edifícios',
 '414215-Conferente de carga e descarga',
 '322205-Técnico de enfermagem',
 '514225-Trabalhador de serviços de limpeza e conservação de áreas públicas',
 '391205-Inspetor de qualidade',
 '521135-Frentista',
 '252405-Analista de recursos humanos',
 '517410-Porteiro',
 '414110-Armazenista',
 '411005-AUXILIAR DE ESCRITORIO EM GERAL',
 '414125-Auxiliar de estoque',
 '252105-Administrador',
 '354145-Vendedor pracista',
 '411005-Auxiliar de escritório, em geral',
 '411005-Auxiliares administrativos e de escritórios',
 '414105-ALMOXARIFE',
 '514310-Auxiliar de manutenção predial',
 '724315-Soldador',
 '411005-Auxiliar de administração',
 '622505-Trabalhador no cultivo de árvores frutíferas',
 '512105-Caseiro',
 '411005-Auxiliar de estoque',
 '784205-Auxiliar de linha de produção',
 '422315-Operador de telemarketing receptivo',
 '422305-Operador de telemarketing ativo',
 '514325-Oficial de serviços gerais',
 '322230-Auxiliar de enfermagem',
 '414105-Conferente de mercadoria',
 '512120-Empregado doméstico diarista',
 '783225-Ajudante de motorista',
 '521115-Promotor de vendas',
 '622110-Trabalhador da cultura de cana-de-açúcar',
 '782310-Motorista de furgão ou veículo similar',
 '521105-Vendedor em comércio atacadista',
 '142320-Gerente de vendas',
 '622020-Trabalhador volante da agricultura',
 '513405-GARCOM',
 '784105-Embalador, a mão',
 '512105-EMPREGADO  DOMESTICO  NOS SERVICOS GERAIS',
 '521110-Vendedor interno',
 '141410-Comerciante varejista',
 '331110-Auxiliar de desenvolvimento infantil',
 '514110-Manobrista',
 '641015-Tratorista agrícola',
 '513205-COZINHEIRO GERAL',
 '141510-Gerente de restaurante',
 '848510-Açougueiro',
 '782220-Operador de empilhadeira',
 '514325-Trabalhador da manutenção de edificações',
 '212405-Analista de desenvolvimento de sistemas',
 '414110-Auxiliar de armazenamento',
 '351605-Técnico em segurança do trabalho',
 '782305-Motorista de carro de passeio',
 '421105-ATENDENTE COMERCIAL ',
 '354130-Promotor de vendas especializado',
 '519110-Motofretista',
 '313220-Técnico em manutenção de equipamentos de informática',
 '763210-Costureiro na confecção em série',
 '252210-Contador']

# %%
#Mesma proporcao do dataset de trabalhadores
escolaridades = ['Médio Completo',
 'Médio Completo',
 'Médio Completo',
 'Médio Completo',
 'Médio Completo',
 'Superior Completo',
 'Fundamental Completo',
 'Nenhum',
 'Mestrado']

# %%
#Mesma proporcao do dataset de trabalhadores
graduacoes = ['pedagogia',
 'direito',
 'administração',
 'ciencias contabeis',
 'logistica',
 'enfermagem',
 'psicologia',
 'engenharia civil',
 'marketing',
 'letras',
 'publicidade e propaganda',
 'fisioterapia',
 'farmacia',
 'educação fisica',
 'engenharia mecanica',
 'gestao financeira',
 'turismo',
 'jornalismo',
 'serviço social',
 'engenharia eletrica',
 'nutrição',
 'biomedicina',
 'comercio exterior',
 'economia',
 'engenharia de produção',
 'arquitetura',
 'processos gerenciais',
 'arquitetura e urbanismo',
 'gestao de recursos humanos',
 'gastronomia',
 'gestão financeira',
 'gestao comercial',
 'quimica',
 'matematica',
 'historia',
 'gestão de recursos humanos',
 'biologia',
 'servico social',
 'ciencias da computação',
 'SERVIÇO SOCIAL',
 'radiologia',
 'analise e desenvolvimento de sistemas',
 'comunicação social',
 'odontologia',
 'engenharia quimica',
 'GESTAO FINANCEIRA',
 'ciências contábeis']

# %%
industrias = [
'Comércio', 
'Administrativo', 
'Logística', 
'Hotelaria e Turismo', 
'Informática', 
'Limpeza', 
'Financeiro', 
'Saúde', 
'Manutenção', 
'Contabilidade', 
'Recursos Humanos', 
'Produção', 
'Construção', 
'Educação', 
'Marketing', 
'Consultoria', 
'Gráfica', 
'Serviços Pessoais', 
'Metal Mecânico', 
'Têxteis', 
'Serviços Domésticos', 
'Mecânico', 
'Farmacêutico', 
'Elétrico', 
'Segurança', 
'Jurídico', 
'Veículos', 
'Alimentos', 
'Agronegócios', 
'Imobiliária', 
'Metalurgia', 
'Móveis', 
'Comunicação', 
'Eletrônico', 
'Químico', 
'Telecomunicações', 
'Internacional', 
'Arte e Cultura', 
'Energia', 
'Esporte', 
'Água e Esgoto', 
'Forças Armadas', 
'Minerais', 
'Social', 
'Extração', 
'Madeira', 
'Biologia', 
'Administração Pública', 
'Plástico', 
'Papel', 
'Locação', 
'Petróleo', 
'Associações e Diversos', 
'Acessórios', 
'Bebidas', 
'Fumo' 
]

# %%
cidades = ['SAO PAULO',
 'GUARULHOS',
 'CAMPINAS',
 'OSASCO',
 'SAO BERNARDO DO CAMPO',
 'SOROCABA',
 'SAO JOSE DOS CAMPOS',
 'SANTO ANDRE',
 'RIBEIRAO PRETO',
 'MAUA',
 'DIADEMA',
 'BARUERI',
 'CARAPICUIBA',
 'ITAQUAQUECETUBA',
 'FRANCA',
 'ITAPEVI',
 'JUNDIAI',
 'SAO VICENTE',
 'INDAIATUBA',
 'SAO JOSE DO RIO PRETO',
 'COTIA',
 'SAO CARLOS',
 'HORTOLANDIA',
 'TABOAO DA SERRA',
 'PRAIA GRANDE',
 'SANTOS',
 'SUMARE',
 'LIMEIRA',
 'PIRACICABA',
 'MOGI DAS CRUZES',
 'JACAREI',
 'BAURU',
 'SUZANO',
 'EMBU DAS ARTES',
 'FRANCISCO MORATO',
 'ITAPECERICA DA SERRA',
 'TAUBATE',
 'ITAPETININGA',
 'RIO CLARO',
 'ITU',
 'BRAGANCA PAULISTA',
 'PRESIDENTE PRUDENTE',
 'FERRAZ DE VASCONCELOS',
 'ARARAQUARA',
 'SANTANA DE PARNAIBA',
 'JAU',
 'PINDAMONHANGABA',
 'JANDIRA',
 'AMERICANA',
 'BIRIGUI',
 'MARILIA',
 'ATIBAIA',
 'GUARUJA',
 'ARACATUBA',
 'FRANCO DA ROCHA',
 'SALTO',
 'ARARAS',
 'CUBATAO',
 'LEME',
 'SANTA BARBARA D OESTE',
 'VOTORANTIM',
 'RIBEIRAO PIRES',
 'TATUI',
 'VOTUPORANGA',
 'MOGI GUACU',
 'ARUJA',
 'VALINHOS',
 'CATANDUVA',
 'VARZEA PAULISTA',
 'CAJAMAR',
 'BARRETOS',
 'OURINHOS',
 'CAIEIRAS',
 'CARAGUATATUBA',
 'SERTAOZINHO',
 'MOGI MIRIM',
 'GUARATINGUETA',
 'LORENA',
 'VINHEDO',
 'SAO CAETANO DO SUL',
 'LENCOIS PAULISTA',
 'ASSIS',
 'CAPIVARI',
 'POA',
 'CACAPAVA',
 'ITATIBA',
 'BOTUCATU',
 'ITUPEVA',
 'BEBEDOURO',
 'JAGUARIUNA',
 'SERRANA',
 'ITAPIRA',
 'SAO JOAO DA BOA VISTA',
 'EMBU-GUACU',
 'TAQUARITINGA',
 'PAULINIA',
 'ITANHAEM',
 'PEDERNEIRAS',
 'ITAPEVA',
 'UBATUBA']

# %%
fake = Faker('pt_BR')

# %%
vagas = []
tipos_emprego= []
#print(fake.name())
for i in range (1, 100001):
    id_empresa = uuid.uuid4()
    nome_empresa = fake.bs()
    posicao = random.choice(job_list)
    #localizacao = fake.city()
    cidade = random.choice(cidades)
    escolaridade = random.choice(escolaridades)
    industria = random.choice(industrias)
    
    if(escolaridade == 'Superior Completo' or escolaridade == 'Mestrado'):
        graduacao = random.choice(graduacoes)
    else:
        graduacao = 'Nenhum'
    
    vagas.append({'id_empresa':id_empresa, 
                  'nome_empresa':nome_empresa, 
                  'posicao':posicao,
                  'cidade': cidade,
                  'escolaridade': escolaridade,
                  'graduacao': graduacao,
                  'industria': industria})

# %%
df_vagas = pd.DataFrame(vagas)

# %%
df_vagas.head()
# Out:
#         cidade          escolaridade graduacao  \
# 0   PIRACICABA        Médio Completo    Nenhum
# 1     CAIEIRAS  Fundamental Completo    Nenhum
# 2  PEDERNEIRAS  Fundamental Completo    Nenhum
# 3     VALINHOS        Médio Completo    Nenhum
# 4      DIADEMA        Médio Completo    Nenhum
#
#                              id_empresa   industria  \
# 0  cd717d64-1c29-4bfe-b074-005ab8034621    Produção
# 1  f71c2bd0-6f3f-4bd0-83b6-8402d65830c5    Petróleo
# 2  d7034759-ba70-4f97-8bf9-7fd503339852        Fumo
# 3  86ef07ac-4e84-4479-aa89-1d111a99240e  Financeiro
# 4  8faea19c-6d81-49f6-8148-fb96e0b3c473    Comércio
#
#                       nome_empresa  \
# 0            enhance B2B mindshare
# 1      implement killer e-commerce
# 2  e-enable cutting-edge e-markets
# 3   reinvent real-time convergence
# 4        benchmark killer networks
#
#                                              posicao
# 0                         641015-Tratorista agrícola
# 1                    414105-Auxiliar de almoxarifado
# 2                        421105-ATENDENTE COMERCIAL
# 3  411005-Auxiliares administrativos e de escritó...
# 4               782305-Motorista de carro de passeio

# %% [markdown]
# ## Checando estabilidade do dataset

# %%
df_vagas.posicao.value_counts().plot.bar(figsize=(20,10));

# %%
df_vagas.escolaridade.value_counts().plot.bar(figsize=(20,10));

# %%
df_vagas.graduacao.value_counts().plot.bar(figsize=(20,10));

# %%
df_vagas.to_csv("data/vagas_mock.csv", index=False)
